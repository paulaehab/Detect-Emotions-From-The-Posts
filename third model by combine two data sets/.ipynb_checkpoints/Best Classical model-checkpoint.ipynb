# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud
from sklearn.feature_extraction.text import TfidfVectorizer ,ENGLISH_STOP_WORDS

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from nltk.tokenize import word_tokenize
import re 
import string
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from sklearn.linear_model import PassiveAggressiveClassifier
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# # 1- Make a data set with all emotions

# %% [markdown]
# ### Merge The two datasets to get neutral emotion

# %%
df1 = pd.read_csv('./First Data/training.csv')
df1.shape
# Out:
# (16000, 2)

# %%
df3 = pd.read_csv('./Third Data/tweet_emotions.csv')
df3.shape
# Out:
# (40000, 3)

# %%
df3 = df3[df3.sentiment == 'neutral'] 

df3.shape
# Out:
# (8638, 3)

# %%
df3=df3[:200]
df3.shape
# Out:
# (200, 3)

# %%
df3.head()
# Out:
#       tweet_id sentiment                                            content
# 4   1956968416   neutral  @dannycastillo We want to trade with someone w...
# 10  1956969456   neutral                                   cant fall asleep
# 22  1956972116   neutral  No Topic Maps talks at the Balisage Markup Con...
# 31  1956975441   neutral                          @cynthia_123 i cant sleep
# 32  1956975860   neutral                    I missed the bl***y bus!!!!!!!!

# %% [markdown]
# ### Drop the id column

# %%
df3.drop(['tweet_id'],axis=1,inplace = True)

# %%
df3.head()
# Out:
#    sentiment                                            content
# 4    neutral  @dannycastillo We want to trade with someone w...
# 10   neutral                                   cant fall asleep
# 22   neutral  No Topic Maps talks at the Balisage Markup Con...
# 31   neutral                          @cynthia_123 i cant sleep
# 32   neutral                    I missed the bl***y bus!!!!!!!!

# %% [markdown]
# ### Rename the coulmns names

# %%
df3.rename(
    columns={"sentiment":"label",
                "content":"text",
                   }
          ,inplace=True)
df3.head()
# Out:
#       label                                               text
# 4   neutral  @dannycastillo We want to trade with someone w...
# 10  neutral                                   cant fall asleep
# 22  neutral  No Topic Maps talks at the Balisage Markup Con...
# 31  neutral                          @cynthia_123 i cant sleep
# 32  neutral                    I missed the bl***y bus!!!!!!!!

# %% [markdown]
# ### insert value 6 insted of neutral word

# %%
df3.label =int(6) 
df3.head()
# Out:
#     label                                               text
# 4       6  @dannycastillo We want to trade with someone w...
# 10      6                                   cant fall asleep
# 22      6  No Topic Maps talks at the Balisage Markup Con...
# 31      6                          @cynthia_123 i cant sleep
# 32      6                    I missed the bl***y bus!!!!!!!!

# %% [markdown]
# ### Concat the two datasets

# %%
df = pd.concat([df1, df3], ignore_index = True, axis = 0)
df.shape
# Out:
# (16200, 2)

# %% [markdown]
# ### shuffle the data set

# %%
df=df.sample(frac = 1)

# %%
df.head()
#label_dict = {0:'sad', 1:'happy', 2:'love', 3:'angry', 4:'fear', 5:'surprise',6:'neutral'}
# Out:
#                                                     text  label
# 10768  i lived with someone living a lie to keep me i...      1
# 5980   i feel so sympathetic embarrassed for betty he...      2
# 1156   i want her to be able to trust me with everyth...      1
# 12204                                          one night      1
# 4065   i pray for those who are feeling unloved and l...      0

# %% [markdown]
# ### drop the fear and surprise emotions

# %%
df = df[df.label != 4] #& 'boredom' & 'enthusiasm' & 'empty'
df = df[df.label != 5]

df = df[df.label != 'sentiment']
df.head()
# Out:
# /home/paula/anaconda3/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)
#                                                     text  label
# 10768  i lived with someone living a lie to keep me i...      1
# 5980   i feel so sympathetic embarrassed for betty he...      2
# 1156   i want her to be able to trust me with everyth...      1
# 12204                                          one night      1
# 4065   i pray for those who are feeling unloved and l...      0

# %%
#label_dict = {0:'sad', 1:'happy', 2:'love', 3:'angry',6:'neutral'}

sns.countplot(df['label'],order = df['label'].value_counts(normalize=True).index)

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# 1- clean any HTML tags in the text

# %%
def clean_html(text):
    
    clean = re.compile('<.*?>')
    return re.sub(clean, '',text)
    
df['text']=df['text'].apply(clean_html)
df.head()
# Out:
#                                                     text  label
# 10768  i lived with someone living a lie to keep me i...      1
# 5980   i feel so sympathetic embarrassed for betty he...      2
# 1156   i want her to be able to trust me with everyth...      1
# 12204                                          one night      1
# 4065   i pray for those who are feeling unloved and l...      0

# %% [markdown]
# 2- convert all the text into lower case

# %%
def convert_lower(text):
    return text.lower()

df['text']=df['text'].apply(convert_lower)
df.head()
# Out:
#                                                     text  label
# 10768  i lived with someone living a lie to keep me i...      1
# 5980   i feel so sympathetic embarrassed for betty he...      2
# 1156   i want her to be able to trust me with everyth...      1
# 12204                                          one night      1
# 4065   i pray for those who are feeling unloved and l...      0

# %% [markdown]
# 3- clean the Tag sign and Tag name (ex:@Paula)

# %%
def cleaning_tags(text):
    return ' '.join(re.sub("([@#][A-Za-z0-9_]+)|(\w+:\/\/\S+)"," ", text).split())

df['text'] = df['text'].apply(lambda x: cleaning_tags(x))
df['text'].head()
# Out:
# 10768    i lived with someone living a lie to keep me i...
# 5980     i feel so sympathetic embarrassed for betty he...
# 1156     i want her to be able to trust me with everyth...
# 12204                                            one night
# 4065     i pray for those who are feeling unloved and l...
# Name: text, dtype: object

# %% [markdown]
# 4- clean all the punctuations

# %%
english_punctuations = string.punctuation
punctuations_list = english_punctuations
def cleaning_punctuations(text):
    translator = str.maketrans('', '', punctuations_list)
    return text.translate(translator)
df['text']= df['text'].apply(lambda x: cleaning_punctuations(x))
df['text'].head()
# Out:
# 10768    i lived with someone living a lie to keep me i...
# 5980     i feel so sympathetic embarrassed for betty he...
# 1156     i want her to be able to trust me with everyth...
# 12204                                            one night
# 4065     i pray for those who are feeling unloved and l...
# Name: text, dtype: object

# %%
#def cleaning_repeating_char(text):
 #   return re.sub(r'([a-z])\1+', r'\1', text)
#df['text'] = df['text'].apply(lambda x: cleaning_repeating_char(x))
#df['text'].head()
# Out:
# 8643     i should fel blesed to have but what about me ...
# 5929                 i fel my iner hapy present once again
# 13308    i was tempted at first to name one of the many...
# 3265     i am living a joyful life and i fel this divin...
# 12848    i always fel a bit triumphant when i find a gi...
# Name: text, dtype: object

# %% [markdown]
# 5- clean the urls founded in the tweets

# %%
def cleaning_URLs(data):
    return re.sub('((www.[^s]+)|(https?://[^s]+))',' ',data)
df['text'] = df['text'].apply(lambda x: cleaning_URLs(x))
df['text'].head()
# Out:
# 10768    i lived with someone living a lie to keep me i...
# 5980     i feel so sympathetic embarrassed for betty he...
# 1156     i want her to be able to trust me with everyth...
# 12204                                            one night
# 4065     i pray for those who are feeling unloved and l...
# Name: text, dtype: object

# %% [markdown]
# 6- clean all numbers

# %%
def cleaning_numbers(data):
    return re.sub('[0-9]+', '', data)
df['text'] = df['text'].apply(lambda x: cleaning_numbers(x))
df['text'].head()
# Out:
# 10768    i lived with someone living a lie to keep me i...
# 5980     i feel so sympathetic embarrassed for betty he...
# 1156     i want her to be able to trust me with everyth...
# 12204                                            one night
# 4065     i pray for those who are feeling unloved and l...
# Name: text, dtype: object

# %% [markdown]
# 7-remove stopwords from data

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords

stop_words = stopwords.words('english')
df['text'] = df['text'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop_words)]))
df.head()
# Out:
# [nltk_data] Downloading package stopwords to /home/paula/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#                                                     text  label
# 10768  lived someone living lie keep dark feeding lie...      1
# 5980      feel sympathetic embarrassed betty tough watch      2
# 1156   want able trust everything want feel like valu...      1
# 12204                                          one night      1
# 4065                         pray feeling unloved lonely      0

# %% [markdown]
# 8- stem words in data

# %%
from nltk.stem.porter import PorterStemmer
ps= PorterStemmer()
y=[]

def stem_words(text):
    for i in text:
        y.append(ps.stem(i))
    z=y[:]
    y.clear()
    return z
df['text']=df['text'].apply(stem_words)
df.head()
# Out:
#                                                     text  label
# 10768  [l, i, v, e, d,  , s, o, m, e, o, n, e,  , l, ...      1
# 5980   [f, e, e, l,  , s, y, m, p, a, t, h, e, t, i, ...      2
# 1156   [w, a, n, t,  , a, b, l, e,  , t, r, u, s, t, ...      1
# 12204                        [o, n, e,  , n, i, g, h, t]      1
# 4065   [p, r, a, y,  , f, e, e, l, i, n, g,  , u, n, ...      0

# %% [markdown]
# 9- join back after stemming

# %%
def joinback2(list_input):
    return "".join(list_input)
    


df['text']=df['text'].apply(joinback2)
df.head()
# Out:
#                                                     text  label
# 10768  lived someone living lie keep dark feeding lie...      1
# 5980      feel sympathetic embarrassed betty tough watch      2
# 1156   want able trust everything want feel like valu...      1
# 12204                                          one night      1
# 4065                         pray feeling unloved lonely      0

# %% [markdown]
# ### Exploratory data analysis

# %% [markdown]
# 1- Sad Emotion

# %%
txt = ' '.join(text for text in df[df['label']==0]['text'])

wordcloud = WordCloud(
            background_color = 'white',
            max_font_size = 100,
            max_words = 200,
            width = 800,
            height = 500
            ).generate(txt)


plt.imshow(wordcloud,interpolation = 'bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# 2- Happy Emotion

# %%
txt = ' '.join(text for text in df[df['label']==1]['text'])

wordcloud = WordCloud(
            background_color = 'white',
            max_font_size = 100,
            max_words = 200,
            width = 800,
            height = 500
            ).generate(txt)


plt.imshow(wordcloud,interpolation = 'bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# 3- Love Emotion

# %%
txt = ' '.join(text for text in df[df['label']==2]['text'])

wordcloud = WordCloud(
            background_color = 'white',
            max_font_size = 100,
            max_words = 200,
            width = 800,
            height = 500
            ).generate(txt)


plt.imshow(wordcloud,interpolation = 'bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# 4-Angry Emotion

# %%
txt = ' '.join(text for text in df[df['label']==3]['text'])

wordcloud = WordCloud(
            background_color = 'white',
            max_font_size = 100,
            max_words = 200,
            width = 800,
            height = 500
            ).generate(txt)


plt.imshow(wordcloud,interpolation = 'bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# 5- Neutral Emotion

# %%
txt = ' '.join(text for text in df[df['label']==6]['text'])

wordcloud = WordCloud(
            background_color = 'white',
            max_font_size = 100,
            max_words = 200,
            width = 800,
            height = 500
            ).generate(txt)


plt.imshow(wordcloud,interpolation = 'bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# ### split data

# %%
X=df['text']
y=df.label
X_train, X_test, y_train,y_test = train_test_split(X,y,test_size=0.3)

# %% [markdown]
# ### Transfer data into numerical features using TFIDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vec = TfidfVectorizer(binary=True, use_idf=True)
X_train = vec.fit_transform(X_train) 
X_test = vec.transform(X_test)

# %%
X_test.shape
# Out:
# (4108, 11502)

# %% [markdown]
# ### Try first model passive aggressive classfier

# %%
pac=PassiveAggressiveClassifier(max_iter=50)
pac.fit(X_train,y_train)
# Out:
# PassiveAggressiveClassifier(max_iter=50)

# %%
y_pred=pac.predict(X_test)
score=accuracy_score(y_test,y_pred)
print(f'Accuracy: {round(score*100,2)}%')
# Out:
# Accuracy: 89.53%

# %% [markdown]
# ### Try second model : logistic regression

# %%
log_reg = LogisticRegression(max_iter=50).fit(X_train, y_train)
# Out:
# /home/paula/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %%
y_predicted = log_reg.predict(X_test)
score=accuracy_score(y_test,y_predicted)
print(f'Accuracy: {round(score*100,2)}%')
# Out:
# Accuracy: 87.54%

# %% [markdown]
# ### Try third model : xgboost

# %%
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score
model = XGBClassifier(use_label_encoder=False, eval_metric='mlogloss', n_estimators=100,learning_rate=0.2)

# %%
model.fit(X_train, y_train)
# Out:
# [20:10:02] WARNING: /workspace/src/learner.cc:480:
# Parameters: { use_label_encoder } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, eval_metric='mlogloss',
#               gamma=0, gpu_id=-1, importance_type='gain',
#               interaction_constraints='', learning_rate=0.2, max_delta_step=0,
#               max_depth=6, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=100, n_jobs=0,
#               num_parallel_tree=1, objective='multi:softprob', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=None, subsample=1,
#               tree_method='exact', use_label_encoder=False,
#               validate_parameters=1, verbosity=None)

# %%
y_pred = model.predict(X_test)
score=accuracy_score(y_test,y_pred)
print(f'Accuracy: {round(score*100,2)}%')
# Out:
# Accuracy: 89.53%

# %% [markdown]
# ### Testing

# %%
Lines=['i have a feeling that the robin that builds her next under our deck is getting pissed too']
#Lines = cv.transform(Lines)
Lines =vec.transform(Lines)
scores = pac.predict(Lines)  
#Prob score for both classes (Good/bad) 
score = scores[0]
if score == 0:
    print('The post is sad')
elif score ==1:
    print('The post is happy')
elif score == 2:
     print('The post is Love')
elif score == 3 :
    print('The post is anger')

elif score == 6 :
    print('the post is Neutral ')
# Out:
# The post is anger
